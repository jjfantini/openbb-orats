# %%
# %load_ext autoreload
# %autoreload 2

from openbb_orats import obb

# %%
import openbb_orats


openbb_orats.build()

# %%
obb.openbb_orats.model_example("AAPL")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\jjfan\github\openbb-orats\menv\Lib\site-packages\openbb_core\provider\query_executor.py:98, in QueryExecutor.execute(self, provider_name, model_name, params, credentials, **kwargs)
#      97 try:
# ---> 98     return await fetcher.fetch_data(params, filtered_credentials, **kwargs)
#      99 except Exception as e:
#
# File c:\Users\jjfan\github\openbb-orats\menv\Lib\site-packages\openbb_core\provider\abstract\fetcher.py:88, in Fetcher.fetch_data(cls, params, credentials, **kwargs)
#      85 data = await maybe_coroutine(
#      86     cls.extract_data, query=query, credentials=credentials, **kwargs
#      87 )
# ---> 88 return cls.transform_data(query=query, data=data, **kwargs)
#
# ...
