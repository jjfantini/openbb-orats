# %%
from openbb_orats import obb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from openbb_orats import obb
#
# File c:\Users\jjfan\github\openbb-orats\openbb_orats\__init__.py:5
#       2 from pathlib import Path
#       3 from typing import List, Optional, Union
# ----> 5 from openbb_core.app.static.app_factory import BaseApp as _BaseApp
#       6 from openbb_core.app.static.app_factory import create_app as _create_app
#       7 from openbb_core.app.static.package_builder import \
#       8     PackageBuilder as _PackageBuilder
#
# File c:\Users\jjfan\github\openbb-orats\menv\Lib\site-packages\openbb_core\app\static\app_factory.py:5
#       1 """App factory."""
#       3 from typing import Optional, Type, TypeVar
# ----> 5 from openbb_core.app.command_runner import CommandRunner
#       6 from openbb_core.app.model.system_settings import SystemSettings
# ...
